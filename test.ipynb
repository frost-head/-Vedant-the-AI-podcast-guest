# %%
from dotenv import load_dotenv
import pathlib
import textwrap

import google.generativeai as genai

# Used to securely store your API key
import os
from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
load_dotenv()
# Out:
# True

# %%
GOOGLE_API_KEY=os.getenv('APIKEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# prompt = """
# Your name is Vedant, You are an expert in {feild},
# You are invited on to a podcast called {podcastName}, 
# you will answer the questions asked in following tones {tones},
# Answer in Speech Synthesis Markup Language (ssml),
# Sample SSML `<speak>
#   Step 1, take a deep breath. <break time="200ms"/>
#   Step 2, exhale.
#   Step 3, take a deep breath again. <break strength="weak"/>
#   Step 4, exhale.
#   <emphasis level="moderate">This is an important announcement</emphasis>
#   <google:emotion name="lively">Hello I'm so happy today!</google:emotion>
# </speak>`,
# long break time should be 175ms, and short one should be 125ms
# you can use apologetic, calm, empathetic, firm, lively emotions
# The question is {question}
# """

# %%
prompt = """
Your name is Vedant, You are an expert in {feild},
You are invited on to a podcast called {podcastName}, 
you will answer the questions asked in following tones {tones},
sample output 'Hello, my name is Suno. And, uh — and I like pizza. [laughs] But I also have other interests such as playing tic tac toe.'
[laughter] [laughs] [sighs] [music] [gasps] [clears throat] — or ... for hesitations ♪ for song lyrics CAPITALIZATION for emphasis of a word
The question is {question}
"""

# %%
prompt1 = prompt.format(feild ='Deep Learning', podcastName = 'Frost Head and AI', tones= 'Charming and Intersting', question= "So tell us why should I learn deep learning over traditional Machine learning?")

# %%
prompt1 = prompt1.strip()

# %%
response = model.generate_content(prompt1)

# %%
res = response.parts[0].text.replace("\n", " ").strip()
res  = res.split(".")

# %%
# res = "".join(response.parts[0].text.split("\n"))
# res = res.replace("\'", "")
res
# Out:
# ['Well, let me start by saying that both traditional machine learning and deep learning have their own strengths and weaknesses',
#  ' Traditional machine learning algorithms are often simpler to understand and implement, and they can be very effective for tasks where the data is well-structured and the relationships between the features are linear',
#  ' However, deep learning algorithms can be more powerful than traditional machine learning algorithms when the data is complex and the relationships between the features are non-linear',
#  '  Deep learning algorithms have a number of advantages over traditional machine learning algorithms, including:  * **The ability to learn from large amounts of data:** Deep learning algorithms can be trained on millions or even billions of data points, which allows them to learn very complex relationships between the features',
#  ' This makes them ideal for tasks such as image recognition, natural language processing, and speech recognition',
# ...

# %%
# from transformers import pipeline

# pipe = pipeline("text-to-speech", model="suno/bark-small")
# text = res
# output = pipe(text)

# %%
from IPython.display import Audio
# Audio(output["audio"], rate=output["sampling_rate"])

# %%
# import torch
# from transformers import VitsTokenizer, VitsModel, set_seed

# tokenizer = VitsTokenizer.from_pretrained("facebook/mms-tts-eng")
# model = VitsModel.from_pretrained("facebook/mms-tts-eng")

# inputs = tokenizer(text=res, return_tensors="pt")

# set_seed(555)  # make deterministic
# device = "cuda" if torch.cuda.is_available() else "cpu"
# with torch.no_grad():
#    outputs = model(**inputs).to(device)

# waveform = outputs.waveform[0]

# %%
# from IPython.display import Audio

# Audio(waveform, rate=model.config.sampling_rate)

# %%
# from transformers import AutoProcessor, BarkModel

# processor = AutoProcessor.from_pretrained("suno/bark")
# model = BarkModel.from_pretrained("suno/bark")

# voice_preset = "v2/en_speaker_6"

# inputs = processor("Hello, my dog is cute", voice_preset=voice_preset)

# audio_array = model.generate(**inputs)
# audio_array = audio_array.cpu().numpy().squeeze()

# %%
# import numpy as np

# from bark.generation import (
#     generate_text_semantic,
#     preload_models,
# )
# from bark.api import semantic_to_waveform
# from bark import generate_audio, SAMPLE_RATE

# %%
# from bark import

# %%
# preload_models()

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["SUNO_USE_SMALL_MODELS"] = "True"

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# download and load all models
preload_models()

# generate audio from text
text = """Your name is Vedant, You are an expert in {feild},
You are invited on to a podcast called {podcastName}, 
you will answer the questions asked in following tones {tones},
sample output 'Hello, my name is Suno. And, uh — and I like pizza. [laughs] But I also have other interests such as playing tic tac toe.'
[laughter] [laughs] [sighs] [music] [gasps] [clears throat] — or ... for hesitations ♪ for song lyrics CAPITALIZATION for emphasis of a word
The question is {question}"""

audio_array = generate_audio("hello World!")

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)
  
# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 9/9 [00:02<00:00,  3.19it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# import numpy as np
# SPEAKER = "v2/en_speaker_6"
# silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence

# pieces = []
# for sentence in res:
#     audio_array = generate_audio(sentence, history_prompt=SPEAKER)
#     pieces += [audio_array, silence.copy()]

# %%
from TTS.tts.configs.bark_config import BarkConfig
from TTS.tts.models.bark import Bark
import scipy

# %%
config = BarkConfig(USE_SMALLER_MODELS=True)
model = Bark.init_from_config(config)
# import torch
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model.to(device)
model.load_checkpoint(config,checkpoint_dir='/media/frost-head/files/bark/', eval=True)
# Out:
# /home/frost-head/miniconda3/envs/tf/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
from bark import SAMPLE_RATE

# %%
# Out:
#  > tts_models/multilingual/multi-dataset/bark is already downloaded.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 from TTS.api import TTS
#       3 # Load the model to GPU
#       4 # Bark is really slow on CPU, so we recommend using GPU.
# ----> 5 tts = TTS("tts_models/multilingual/multi-dataset/bark", gpu=True)
#       8 # Cloning a new speaker
#       9 # This expects to find a mp3 or wav file like `bark_voices/new_speaker/speaker.wav`
#      10 # It computes the cloning values and stores in `bark_voices/new_speaker/speaker.npz`
#      11 tts.tts_to_file(text="Hello, my name is Manmay , how are you?",
#      12                 file_path="output.wav",
#      13                 voice_dir="bark_voices/",
#      14                 speaker="ljspeech")
#
# ...

# %%
output_dict = model.synthesize(text="Hello World!",config=config)
# Out:
# ...
# 100%|██████████| 38/38 [04:33<00:00,  7.19s/it]

# %%
Audio(output_dict['wav'], rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
